# %%
# setup code checking 
from learntools.core import binder
binder.bind(globals())
from learntools.machine_learning.ex2 import *
print("Setup Complete")
# Out:
# Setup Complete

# %%
import pandas as pd

# %%
# save file path to variable for easier access
learning_file_path = '../input/learning/melb_data.csv'
# read the data and stroe the data in a DataFrame titled learning_data
learning_data = pd.read_csv(learning_file_path)
# print a summary of the data in Learning data
learning_data.describe()

# %%
# columns property of a DataFrame
learning_data.columns

# %% [markdown]
# # Selecting The Prediction Target
# You can pull out a variable with dot-notation. This single column is stored in a Series, which is broadly like a DataFrame with only a single column of data.
# We'll use the dot notation to select the column we want to predict, which is called the prediction target. By convention, the prediction target is called **y**. So the code we need to save the house prices in the Learning data is

# %%
y = learning_data.Price

# %% [markdown]
# # Choosing "Features"
# The columns that are inputted into our model (and later used to make predictions) are called "features." In our case, those would be the columns used to determine the home price. Sometimes, you will use all columns except the target as features. Other times you'll be better off with fewer features.
#
# For now, we'll build a model with only a few features. Later on you'll see how to iterate and compare models built with different features.
#
# We select multiple features by providing a list of column names inside brackets. Each item in that list should be a string (with quotes).
#
# Here is an example:

# %%
learning_features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']

# %% [markdown]
# By convention, this data is called **X**.

# %%
X = learning_data[learning_features]

# %%
X.describe()

# %% [markdown]
# head() method is showing top 5 output

# %%
X.head()

# %%
from sklearn.tree import DecisionTreeRegressor
# Define model. Specify a number for a random_state to ensure same results each run
learning_model1 = DecisionTreeRegressor(random_state=1)

# Fit model
learning_model1.fit(X,y)
